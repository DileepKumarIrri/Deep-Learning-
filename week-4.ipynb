# %%
import pyttsx3
engine = pyttsx3.init()
voices = engine.getProperty('voices')
for i in voices:
    print(i.name)
# Out:
# Microsoft David Desktop - English (United States)
# Microsoft Zira Desktop - English (United States)

# %%
engine.setProperty('voices', 'com.apple.speech.synthesis.voice.Alex')

# %%
engine.say("hello")
engine.runAndWait()
